# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('income.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df["workclass"] = df["workclass"].replace("?", np.nan)
df["occupation"] = df["occupation"].replace("?", np.nan)

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
print((df["workclass"].isna()).sum())
print((df["occupation"].isna()).sum())
print(np.logical_or(df["workclass"].isna(), df["occupation"].isna()).sum())
# Out:
# 2799
# 2809
# 2809

# %%
df[df.isnull().any(axis=1)]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18       NaN  103497  Some-college               10
# 6       29       NaN  227026       HS-grad                9
# 13      58       NaN  299831       HS-grad                9
# 22      72       NaN  132015       7th-8th                4
# 35      65       NaN  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35       NaN  320084     Bachelors               13
# 48812   30       NaN   33811     Bachelors               13
# 48820   71       NaN  287372     Doctorate               16
# 48822   41       NaN  202822       HS-grad                9
# 48823   72       NaN  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married        NaN      Own-child               White
# 6           Never-married        NaN      Unmarried               Black
# ...

# %%
df.sort_values('hours-per-week', ascending=False).head(10)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 35422   59           Private  106748       7th-8th                4
# 2690    37         Local-gov  130805    Assoc-acdm               12
# 39930   45           Private  390368  Some-college               10
# 2392    34           Private  230246       HS-grad                9
# 45468   31           Private  178370       HS-grad                9
# 9299    56         Local-gov  237546  Some-college               10
# 26749   44  Self-emp-not-inc  277783       Masters               14
# 3237    58               NaN  365410  Some-college               10
# 26092   28           Private   27956   Prof-school               15
# 8032    31           Private  307543          10th                6
#
#            marital-status        occupation    relationship  \
# 35422  Married-civ-spouse     Other-service            Wife
# 2690   Married-civ-spouse   Protective-serv         Husband
# ...

# %%
df[df["native-country"] == "Iran"]["hours-per-week"].mean()
# Out:
# 42.94915254237288

# %%
is_female = np.logical_and(df["native-country"] == "Iran", df["gender"] == "Female")
is_female.sum() / len(is_female) * 100
# Out:
# 0.024569018467712214
