# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('income.csv')

# %%
plt.figure(figsize=(10, 10))
plt.scatter(df['age'], df['hours-per-week'], alpha=0.2, s=10, label='World')

df_iran = df[df['native-country']=='Iran']
plt.scatter(df_iran['age'], df_iran['hours-per-week'], alpha=0.4, color='red', s=50, label='Iran')

plt.xlabel('age')
plt.ylabel('hours-per-week')
plt.legend();

# %%
(df[df['race'] == 'Black'].groupby('native-country').sum() / df.groupby('native-country').sum())['age']
# Out:
# native-country
# ?                             0.146653
# Cambodia                      0.044530
# Canada                             NaN
# China                              NaN
# Columbia                           NaN
# Cuba                          0.037674
# Dominican-Republic            0.162618
# Ecuador                       0.013569
# El-Salvador                   0.007924
# England                       0.067612
# France                        0.017624
# Germany                       0.041751
# Greece                             NaN
# Guatemala                          NaN
# Haiti                         0.955786
# Holand-Netherlands                 NaN
# Honduras                      0.185449
# Hong                               NaN
# Hungary                            NaN
# India                         0.017607
# Iran                               NaN
# Ireland                            NaN
# Italy                              NaN
# Jamaica                       0.938532
# Japan                         0.031423
# Laos                               NaN
# Mexico                        0.003970
# Nicaragua                     0.062992
# Outlying-US(Guam-USVI-etc)    0.343785
# Peru                               NaN
# Philippines                   0.005046
# Poland                             NaN
# Portugal                           NaN
# Puerto-Rico                   0.073892
# Scotland                      0.051935
# South                         0.006619
# Taiwan                             NaN
# Thailand                      0.022124
# Trinadad&Tobago               0.791509
# United-States                 0.095605
# Vietnam                            NaN
# Yugoslavia                         NaN
# Name: age, dtype: float64

# %%
plt.figure(figsize=(12, 6))
summary = pd.DataFrame()
summary['blacks-percentage'] = (df[df['race'] == 'Black'].groupby('native-country').sum()['age'] / df.groupby('native-country').sum()['age']).fillna(0) * 100
summary = summary.sort_values('blacks-percentage', ascending=False)

plt.bar(summary.head(5).index, summary.head(5)['blacks-percentage'])
plt.xlabel('country')
plt.ylabel('percentage of black workers');
