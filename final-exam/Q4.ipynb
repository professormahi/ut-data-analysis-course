# %%
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
df = pd.read_excel('q4-data.xlsx', engine='openpyxl')
display(df)
df = df.drop(columns=['day', 'month', 'year', 'popData2019', 'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'])
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-12-14   14     12  2020    746       6             Afghanistan
# 1     2020-12-13   13     12  2020    298       9             Afghanistan
# 2     2020-12-12   12     12  2020    113      11             Afghanistan
# 3     2020-12-11   11     12  2020     63      10             Afghanistan
# 4     2020-12-10   10     12  2020    202      16             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 61895 2020-03-25   25      3  2020      0       0                Zimbabwe
# 61896 2020-03-24   24      3  2020      0       1                Zimbabwe
# 61897 2020-03-23   23      3  2020      0       0                Zimbabwe
# 61898 2020-03-22   22      3  2020      1       0                Zimbabwe
# 61899 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
_['continentExp'].unique()
# Out:
# array(['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other'],
#       dtype=object)

# %%
plt.figure(figsize=(10, 10))
_ = df.groupby(['continentExp', 'countriesAndTerritories']).sum().reset_index()


for c in _['continentExp'].unique():
    plt.scatter(_[_['continentExp'] == c]['cases'], _[_['continentExp'] == c]['deaths'], alpha=0.2, label=c)
    
plt.legend()
plt.xlabel('cases')
plt.ylabel('deaths')
plt.title('Death to Cases Ratio for Covid');
